# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

DATA_ROOT_PATH = "../data/tabular_nov11/"

# %%
train = pd.read_csv(DATA_ROOT_PATH + "train.csv")
test = pd.read_csv(DATA_ROOT_PATH + "test.csv")

# %%
data = pd.concat([train, test], sort=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1140000 entries, 0 to 539999
# Columns: 102 entries, id to target
# dtypes: float64(101), int64(1)
# memory usage: 895.8 MB

# %%
data.head()
# Out:
#    id        f0       f1        f2       f3        f4       f5       f6  \
# 0   0  0.106643  3.59437  132.8040  3.18428  0.081971  1.18859  3.73238
# 1   1  0.125021  1.67336   76.5336  3.37825  0.099400  5.09366  1.27562
# 2   2  0.036330  1.49747  233.5460  2.19435  0.026914  3.12694  5.05687
# 3   3 -0.014077  0.24600  779.9670  1.89064  0.006948  1.53112  2.69800
# 4   4 -0.003259  3.71542  156.1280  2.14772  0.018284  2.09859  4.15492
#
#          f7       f8  ...      f91       f92       f93       f94       f95  \
# 0  2.266270  2.09959  ...  1.09862  0.013331 -0.011715  0.052759  0.065400
# 1 -0.471318  4.54594  ...  3.46017  0.017054  0.124863  0.154064  0.606848
# 2  3.849460  1.80187  ...  4.88300  0.085222  0.032396  0.116092 -0.001688
# 3  4.517330  4.50332  ...  3.47439 -0.017103 -0.008100  0.062013  0.041193
# 4 -0.038236  3.37145  ...  1.91059 -0.042943  0.105616  0.125072  0.037509
#
#         f96      f97       f98       f99  target
# ...

# %%
data.describe()
# Out:
#                  id            f0            f1            f2            f3  \
# count  1.140000e+06  1.140000e+06  1.140000e+06  1.140000e+06  1.140000e+06
# mean   5.699995e+05  3.264759e-01  2.554745e+00  2.862445e+02  2.617506e+00
# std    3.290898e+05  5.440451e-01  1.550218e+00  5.267131e+02  1.537830e+00
# min    0.000000e+00 -3.797450e+00 -1.260150e+00 -1.842530e+03 -1.370560e+00
# 25%    2.849998e+05  3.415255e-02  1.252510e+00  3.568275e+01  1.426217e+00
# 50%    5.699995e+05  1.067375e-01  2.584840e+00  1.251330e+02  2.591650e+00
# 75%    8.549992e+05  4.257685e-01  3.833010e+00  2.686232e+02  3.864190e+00
# max    1.139999e+06  8.781500e+00  6.434070e+00  6.119280e+03  6.521150e+00
#
#                  f4            f5            f6            f7            f8  \
# count  1.140000e+06  1.140000e+06  1.140000e+06  1.140000e+06  1.140000e+06
# mean   1.939282e-01  2.629169e+00  2.729360e+00  2.527915e+00  2.543583e+00
# ...
