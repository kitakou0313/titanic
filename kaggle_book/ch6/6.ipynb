# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("../data/train_preprocessed.csv")
train_x = train.drop(["target"], axis=1)
train_y = train["target"]

test_x = pd.read_csv("../data/test_preprocessed.csv")
test_x = test_x.dropna(how="any")

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]

tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
import lightgbm as lgb
from sklearn.metrics import log_loss

# %%
def evaluate(features):
    dtrain = lgb.Dataset(tr_x[features], label=tr_y)
    dvalid = lgb.Dataset(va_x[features], label=va_y)

    params = {'objective': 'binary', 'seed': 71, 'verbose': 0, 'metrics': 'binary_logloss'}
    num_round = 10

    model = lgb.train(
        params, dtrain, num_boost_round=num_round, valid_names=["train", "valid"], valid_sets=[dtrain, dvalid]
    )

    va_pred = model.predict(va_x[features])

    return log_loss(va_y, va_pred)

# %%
#Greedy forward Selection
# すべての特徴の組み合わせを探索して、最適な組み合わせを探す
# 単純化のため、選択されたものに追加してスコアを改善したものを追加していく

best_score = float("inf")
selected = set([])

# %%
while True:
    if len(selected) == len(train_x.columns):
        break

    scores = []
    for feature in train_x.columns:
        if feature not in selected:
            features_selected = list(selected) + [feature]

            score = evaluate(features_selected)
            scores.append((feature, score))

    
    best_feature, best_score_in_loop = sorted(scores, key=lambda tpl: tpl[1])[0]

    if best_score_in_loop < best_score:
        selected.add(best_feature)
        best_score = best_score_in_loop

        print("Best score", best_score, "Selected features", selected)
    else:
        break


print("Final selected features", selected)
# Out:
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.481952	valid's binary_logloss: 0.491663
# [2]	train's binary_logloss: 0.477722	valid's binary_logloss: 0.488398
# [3]	train's binary_logloss: 0.47433	valid's binary_logloss: 0.485966
# [4]	train's binary_logloss: 0.471627	valid's binary_logloss: 0.484193
# [5]	train's binary_logloss: 0.469454	valid's binary_logloss: 0.482878
# [6]	train's binary_logloss: 0.467708	valid's binary_logloss: 0.481963
# [7]	train's binary_logloss: 0.466295	valid's binary_logloss: 0.481144
# [8]	train's binary_logloss: 0.465128	valid's binary_logloss: 0.480764
# [9]	train's binary_logloss: 0.464177	valid's binary_logloss: 0.480541
# [10]	train's binary_logloss: 0.463425	valid's binary_logloss: 0.480289
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487263	valid's binary_logloss: 0.495885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487169	valid's binary_logloss: 0.495747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487092	valid's binary_logloss: 0.495632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.48703	valid's binary_logloss: 0.495536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.48698	valid's binary_logloss: 0.495455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.486939	valid's binary_logloss: 0.495387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.486906	valid's binary_logloss: 0.49533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.48688	valid's binary_logloss: 0.495281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.486858	valid's binary_logloss: 0.49524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.486841	valid's binary_logloss: 0.495205
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.486072	valid's binary_logloss: 0.495956
# [2]	train's binary_logloss: 0.485009	valid's binary_logloss: 0.495775
# [3]	train's binary_logloss: 0.484103	valid's binary_logloss: 0.495633
# [4]	train's binary_logloss: 0.483311	valid's binary_logloss: 0.495803
# [5]	train's binary_logloss: 0.482643	valid's binary_logloss: 0.495799
# [6]	train's binary_logloss: 0.481914	valid's binary_logloss: 0.495953
# [7]	train's binary_logloss: 0.481329	valid's binary_logloss: 0.496228
# [8]	train's binary_logloss: 0.480803	valid's binary_logloss: 0.496497
# [9]	train's binary_logloss: 0.480391	valid's binary_logloss: 0.49686
# [10]	train's binary_logloss: 0.47994	valid's binary_logloss: 0.497091
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.478792	valid's binary_logloss: 0.489653
# [2]	train's binary_logloss: 0.472658	valid's binary_logloss: 0.485332
# [3]	train's binary_logloss: 0.468055	valid's binary_logloss: 0.482395
# [4]	train's binary_logloss: 0.46455	valid's binary_logloss: 0.480167
# [5]	train's binary_logloss: 0.461559	valid's binary_logloss: 0.478518
# [6]	train's binary_logloss: 0.459093	valid's binary_logloss: 0.477277
# [7]	train's binary_logloss: 0.457123	valid's binary_logloss: 0.476483
# [8]	train's binary_logloss: 0.455504	valid's binary_logloss: 0.475882
# [9]	train's binary_logloss: 0.453995	valid's binary_logloss: 0.475237
# [10]	train's binary_logloss: 0.452719	valid's binary_logloss: 0.474771
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.485233	valid's binary_logloss: 0.493854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.483554	valid's binary_logloss: 0.492151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.482232	valid's binary_logloss: 0.490819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.481184	valid's binary_logloss: 0.489773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.480351	valid's binary_logloss: 0.488948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.479685	valid's binary_logloss: 0.488296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.479152	valid's binary_logloss: 0.487779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.478724	valid's binary_logloss: 0.48737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.47838	valid's binary_logloss: 0.487045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.478103	valid's binary_logloss: 0.486788
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.486613	valid's binary_logloss: 0.49543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.485993	valid's binary_logloss: 0.494941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.48549	valid's binary_logloss: 0.494555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.485084	valid's binary_logloss: 0.494253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.484754	valid's binary_logloss: 0.494016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.484486	valid's binary_logloss: 0.493832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.484269	valid's binary_logloss: 0.49369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.484093	valid's binary_logloss: 0.493581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.483951	valid's binary_logloss: 0.493498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.483835	valid's binary_logloss: 0.493436
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.477484	valid's binary_logloss: 0.488358
# [2]	train's binary_logloss: 0.470077	valid's binary_logloss: 0.482714
# [3]	train's binary_logloss: 0.464206	valid's binary_logloss: 0.478053
# [4]	train's binary_logloss: 0.459415	valid's binary_logloss: 0.474729
# [5]	train's binary_logloss: 0.455558	valid's binary_logloss: 0.471982
# [6]	train's binary_logloss: 0.452448	valid's binary_logloss: 0.470026
# [7]	train's binary_logloss: 0.449809	valid's binary_logloss: 0.468467
# [8]	train's binary_logloss: 0.447632	valid's binary_logloss: 0.467488
# [9]	train's binary_logloss: 0.445869	valid's binary_logloss: 0.466686
# [10]	train's binary_logloss: 0.444336	valid's binary_logloss: 0.465838
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.485027	valid's binary_logloss: 0.494477
# [2]	train's binary_logloss: 0.483174	valid's binary_logloss: 0.493388
# [3]	train's binary_logloss: 0.481669	valid's binary_logloss: 0.492619
# [4]	train's binary_logloss: 0.480324	valid's binary_logloss: 0.491704
# [5]	train's binary_logloss: 0.479209	valid's binary_logloss: 0.491219
# [6]	train's binary_logloss: 0.478359	valid's binary_logloss: 0.491048
# [7]	train's binary_logloss: 0.477548	valid's binary_logloss: 0.490885
# [8]	train's binary_logloss: 0.476876	valid's binary_logloss: 0.49075
# [9]	train's binary_logloss: 0.476225	valid's binary_logloss: 0.490582
# [10]	train's binary_logloss: 0.475497	valid's binary_logloss: 0.49035
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.48648	valid's binary_logloss: 0.495385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.485782	valid's binary_logloss: 0.494903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.485236	valid's binary_logloss: 0.494552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.484806	valid's binary_logloss: 0.4943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.484465	valid's binary_logloss: 0.494121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.484194	valid's binary_logloss: 0.493996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.483977	valid's binary_logloss: 0.493913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.483804	valid's binary_logloss: 0.49386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.483665	valid's binary_logloss: 0.493831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.483553	valid's binary_logloss: 0.493818
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487292	valid's binary_logloss: 0.49609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.48722	valid's binary_logloss: 0.496134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487162	valid's binary_logloss: 0.49618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487115	valid's binary_logloss: 0.496227
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.487077	valid's binary_logloss: 0.496273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487047	valid's binary_logloss: 0.496318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487022	valid's binary_logloss: 0.496361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487002	valid's binary_logloss: 0.496402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.486985	valid's binary_logloss: 0.496441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.486972	valid's binary_logloss: 0.496477
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.48736	valid's binary_logloss: 0.496081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487343	valid's binary_logloss: 0.496111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.48733	valid's binary_logloss: 0.496139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487318	valid's binary_logloss: 0.496166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.487309	valid's binary_logloss: 0.496191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487302	valid's binary_logloss: 0.496215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487296	valid's binary_logloss: 0.496236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487291	valid's binary_logloss: 0.496257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487287	valid's binary_logloss: 0.496275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.487284	valid's binary_logloss: 0.496292
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487211	valid's binary_logloss: 0.495999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487075	valid's binary_logloss: 0.495967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.486965	valid's binary_logloss: 0.495948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.486876	valid's binary_logloss: 0.49594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.486805	valid's binary_logloss: 0.49594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.486747	valid's binary_logloss: 0.495945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.4867	valid's binary_logloss: 0.495954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.486662	valid's binary_logloss: 0.495966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.486632	valid's binary_logloss: 0.495979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.486607	valid's binary_logloss: 0.495994
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.485935	valid's binary_logloss: 0.494707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.484781	valid's binary_logloss: 0.493646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.483857	valid's binary_logloss: 0.492806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.483114	valid's binary_logloss: 0.492138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.482515	valid's binary_logloss: 0.491607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.482031	valid's binary_logloss: 0.491184
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.481641	valid's binary_logloss: 0.490851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.481323	valid's binary_logloss: 0.490584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.481067	valid's binary_logloss: 0.490374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.480858	valid's binary_logloss: 0.490206
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.486034	valid's binary_logloss: 0.496179
# [2]	train's binary_logloss: 0.484969	valid's binary_logloss: 0.496409
# [3]	train's binary_logloss: 0.484101	valid's binary_logloss: 0.496725
# [4]	train's binary_logloss: 0.483378	valid's binary_logloss: 0.497149
# [5]	train's binary_logloss: 0.482767	valid's binary_logloss: 0.497598
# [6]	train's binary_logloss: 0.482266	valid's binary_logloss: 0.498059
# [7]	train's binary_logloss: 0.481842	valid's binary_logloss: 0.498572
# [8]	train's binary_logloss: 0.481493	valid's binary_logloss: 0.498962
# [9]	train's binary_logloss: 0.481144	valid's binary_logloss: 0.499422
# [10]	train's binary_logloss: 0.480865	valid's binary_logloss: 0.499779
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487125	valid's binary_logloss: 0.495778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.486915	valid's binary_logloss: 0.495554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.486743	valid's binary_logloss: 0.495369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.486602	valid's binary_logloss: 0.495216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.486486	valid's binary_logloss: 0.49509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.486391	valid's binary_logloss: 0.494986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.486314	valid's binary_logloss: 0.4949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.486251	valid's binary_logloss: 0.494829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.486199	valid's binary_logloss: 0.494771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.486157	valid's binary_logloss: 0.494722
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.486268	valid's binary_logloss: 0.494479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.485366	valid's binary_logloss: 0.493167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.484634	valid's binary_logloss: 0.492068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.48404	valid's binary_logloss: 0.491145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.483558	valid's binary_logloss: 0.490367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.483167	valid's binary_logloss: 0.48971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.482849	valid's binary_logloss: 0.489154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.482591	valid's binary_logloss: 0.488681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.482382	valid's binary_logloss: 0.488278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.482211	valid's binary_logloss: 0.487934
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.484845	valid's binary_logloss: 0.493202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.482874	valid's binary_logloss: 0.490972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.481329	valid's binary_logloss: 0.48921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.48011	valid's binary_logloss: 0.487807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.479144	valid's binary_logloss: 0.486683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.478375	valid's binary_logloss: 0.485778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.477762	valid's binary_logloss: 0.485047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.477271	valid's binary_logloss: 0.484454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.476877	valid's binary_logloss: 0.483971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.476561	valid's binary_logloss: 0.483577
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.484035	valid's binary_logloss: 0.492942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.481659	valid's binary_logloss: 0.490805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.479902	valid's binary_logloss: 0.489279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.478569	valid's binary_logloss: 0.488168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.477541	valid's binary_logloss: 0.48735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.476739	valid's binary_logloss: 0.486744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.476107	valid's binary_logloss: 0.486295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.475606	valid's binary_logloss: 0.485965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.475207	valid's binary_logloss: 0.485725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.474888	valid's binary_logloss: 0.485552
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.483303	valid's binary_logloss: 0.491289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.480682	valid's binary_logloss: 0.488204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.478814	valid's binary_logloss: 0.485984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.477414	valid's binary_logloss: 0.484301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.47633	valid's binary_logloss: 0.482984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.475475	valid's binary_logloss: 0.48193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.474791	valid's binary_logloss: 0.481073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.474237	valid's binary_logloss: 0.480369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.473787	valid's binary_logloss: 0.479786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.473419	valid's binary_logloss: 0.479299
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487333	valid's binary_logloss: 0.49597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487294	valid's binary_logloss: 0.495902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487263	valid's binary_logloss: 0.495845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487238	valid's binary_logloss: 0.495797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.487217	valid's binary_logloss: 0.495756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487201	valid's binary_logloss: 0.49572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487187	valid's binary_logloss: 0.49569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487176	valid's binary_logloss: 0.495665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487167	valid's binary_logloss: 0.495642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.48716	valid's binary_logloss: 0.495623
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487381	valid's binary_logloss: 0.496054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.48738	valid's binary_logloss: 0.496057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.48738	valid's binary_logloss: 0.49606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.48738	valid's binary_logloss: 0.496063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.48738	valid's binary_logloss: 0.496065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.48738	valid's binary_logloss: 0.496068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487379	valid's binary_logloss: 0.49607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487379	valid's binary_logloss: 0.496072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487379	valid's binary_logloss: 0.496073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.487379	valid's binary_logloss: 0.496075
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487378	valid's binary_logloss: 0.496051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487375	valid's binary_logloss: 0.496052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487373	valid's binary_logloss: 0.496053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487372	valid's binary_logloss: 0.496054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.48737	valid's binary_logloss: 0.496055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487369	valid's binary_logloss: 0.496056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487368	valid's binary_logloss: 0.496057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487368	valid's binary_logloss: 0.496058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487367	valid's binary_logloss: 0.496059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.487367	valid's binary_logloss: 0.49606
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487379	valid's binary_logloss: 0.49606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487377	valid's binary_logloss: 0.496069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487375	valid's binary_logloss: 0.496077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487374	valid's binary_logloss: 0.496085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.487373	valid's binary_logloss: 0.496092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487372	valid's binary_logloss: 0.496098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487372	valid's binary_logloss: 0.496104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487371	valid's binary_logloss: 0.49611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487371	valid's binary_logloss: 0.496114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.48737	valid's binary_logloss: 0.496119
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.48735	valid's binary_logloss: 0.496089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487326	valid's binary_logloss: 0.496127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487305	valid's binary_logloss: 0.496163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487288	valid's binary_logloss: 0.496198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.487275	valid's binary_logloss: 0.496232
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487263	valid's binary_logloss: 0.496263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487254	valid's binary_logloss: 0.496293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487247	valid's binary_logloss: 0.49632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487241	valid's binary_logloss: 0.496346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.487236	valid's binary_logloss: 0.49637
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.48737	valid's binary_logloss: 0.496033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487361	valid's binary_logloss: 0.496019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487354	valid's binary_logloss: 0.496007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.487348	valid's binary_logloss: 0.495996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.487343	valid's binary_logloss: 0.495988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.487339	valid's binary_logloss: 0.49598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.487336	valid's binary_logloss: 0.495974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.487334	valid's binary_logloss: 0.495969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.487331	valid's binary_logloss: 0.495964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.48733	valid's binary_logloss: 0.495961
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.487246	valid's binary_logloss: 0.495919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.487136	valid's binary_logloss: 0.495814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.487048	valid's binary_logloss: 0.495729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.486976	valid's binary_logloss: 0.49566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.486918	valid's binary_logloss: 0.495605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.48687	valid's binary_logloss: 0.495561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.486832	valid's binary_logloss: 0.495526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.486801	valid's binary_logloss: 0.495497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.486776	valid's binary_logloss: 0.495475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.486756	valid's binary_logloss: 0.495456
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.486969	valid's binary_logloss: 0.496053
# [2]	train's binary_logloss: 0.486634	valid's binary_logloss: 0.496092
# [3]	train's binary_logloss: 0.486362	valid's binary_logloss: 0.496156
# [4]	train's binary_logloss: 0.486142	valid's binary_logloss: 0.496238
# [5]	train's binary_logloss: 0.485962	valid's binary_logloss: 0.49633
# [6]	train's binary_logloss: 0.485816	valid's binary_logloss: 0.49643
# [7]	train's binary_logloss: 0.485697	valid's binary_logloss: 0.496532
# [8]	train's binary_logloss: 0.485601	valid's binary_logloss: 0.496634
# [9]	train's binary_logloss: 0.485523	valid's binary_logloss: 0.496735
# [10]	train's binary_logloss: 0.485459	valid's binary_logloss: 0.496833
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's binary_logloss: 0.48717	valid's binary_logloss: 0.495907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's binary_logloss: 0.486999	valid's binary_logloss: 0.495798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's binary_logloss: 0.48686	valid's binary_logloss: 0.495715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's binary_logloss: 0.486748	valid's binary_logloss: 0.495653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's binary_logloss: 0.486657	valid's binary_logloss: 0.495607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's binary_logloss: 0.486583	valid's binary_logloss: 0.495574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's binary_logloss: 0.486523	valid's binary_logloss: 0.495551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's binary_logloss: 0.486474	valid's binary_logloss: 0.495536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's binary_logloss: 0.486435	valid's binary_logloss: 0.495527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's binary_logloss: 0.486403	valid's binary_logloss: 0.495522
# Best score 0.4658379218299636 Selected features {'medical_info_a1'}
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.471669	valid's binary_logloss: 0.48372
# [2]	train's binary_logloss: 0.460065	valid's binary_logloss: 0.474084
# [3]	train's binary_logloss: 0.45088	valid's binary_logloss: 0.467025
# [4]	train's binary_logloss: 0.443617	valid's binary_logloss: 0.461669
# [5]	train's binary_logloss: 0.437633	valid's binary_logloss: 0.457244
# [6]	train's binary_logloss: 0.432751	valid's binary_logloss: 0.454087
# [7]	train's binary_logloss: 0.428473	valid's binary_logloss: 0.451562
# [8]	train's binary_logloss: 0.424701	valid's binary_logloss: 0.449526
# [9]	train's binary_logloss: 0.421724	valid's binary_logloss: 0.447734
# [10]	train's binary_logloss: 0.418875	valid's binary_logloss: 0.4466
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.477166	valid's binary_logloss: 0.488123
# [2]	train's binary_logloss: 0.46942	valid's binary_logloss: 0.48197
# [3]	train's binary_logloss: 0.463343	valid's binary_logloss: 0.477369
# [4]	train's binary_logloss: 0.458433	valid's binary_logloss: 0.473836
# [5]	train's binary_logloss: 0.454464	valid's binary_logloss: 0.471067
# [6]	train's binary_logloss: 0.451168	valid's binary_logloss: 0.468923
# [7]	train's binary_logloss: 0.448437	valid's binary_logloss: 0.467299
# [8]	train's binary_logloss: 0.445969	valid's binary_logloss: 0.466072
# [9]	train's binary_logloss: 0.443926	valid's binary_logloss: 0.465206
# [10]	train's binary_logloss: 0.442199	valid's binary_logloss: 0.464552
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.47643	valid's binary_logloss: 0.488561
# [2]	train's binary_logloss: 0.468107	valid's binary_logloss: 0.482871
# [3]	train's binary_logloss: 0.46155	valid's binary_logloss: 0.478277
# [4]	train's binary_logloss: 0.456263	valid's binary_logloss: 0.475003
# [5]	train's binary_logloss: 0.451678	valid's binary_logloss: 0.471949
# [6]	train's binary_logloss: 0.447752	valid's binary_logloss: 0.470106
# [7]	train's binary_logloss: 0.444168	valid's binary_logloss: 0.468866
# [8]	train's binary_logloss: 0.441424	valid's binary_logloss: 0.467877
# [9]	train's binary_logloss: 0.438845	valid's binary_logloss: 0.466844
# [10]	train's binary_logloss: 0.436671	valid's binary_logloss: 0.465924
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.469805	valid's binary_logloss: 0.482572
# [2]	train's binary_logloss: 0.456719	valid's binary_logloss: 0.472366
# [3]	train's binary_logloss: 0.446724	valid's binary_logloss: 0.464429
# [4]	train's binary_logloss: 0.438541	valid's binary_logloss: 0.458053
# [5]	train's binary_logloss: 0.432033	valid's binary_logloss: 0.452935
# [6]	train's binary_logloss: 0.426616	valid's binary_logloss: 0.449175
# [7]	train's binary_logloss: 0.421738	valid's binary_logloss: 0.446073
# [8]	train's binary_logloss: 0.417638	valid's binary_logloss: 0.443497
# [9]	train's binary_logloss: 0.414258	valid's binary_logloss: 0.441612
# ...
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379526	valid's binary_logloss: 0.397509
# [6]	train's binary_logloss: 0.366313	valid's binary_logloss: 0.386087
# [7]	train's binary_logloss: 0.355367	valid's binary_logloss: 0.375785
# [8]	train's binary_logloss: 0.345658	valid's binary_logloss: 0.367249
# [9]	train's binary_logloss: 0.336508	valid's binary_logloss: 0.360184
# [10]	train's binary_logloss: 0.327584	valid's binary_logloss: 0.352396
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410077	valid's binary_logloss: 0.425543
# [4]	train's binary_logloss: 0.39358	valid's binary_logloss: 0.410625
# [5]	train's binary_logloss: 0.379366	valid's binary_logloss: 0.39763
# [6]	train's binary_logloss: 0.366025	valid's binary_logloss: 0.386742
# [7]	train's binary_logloss: 0.35453	valid's binary_logloss: 0.375287
# [8]	train's binary_logloss: 0.344603	valid's binary_logloss: 0.366117
# [9]	train's binary_logloss: 0.335229	valid's binary_logloss: 0.358732
# [10]	train's binary_logloss: 0.327172	valid's binary_logloss: 0.352215
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	train's binary_logloss: 0.454308	valid's binary_logloss: 0.465515
# [2]	train's binary_logloss: 0.429565	valid's binary_logloss: 0.443444
# [3]	train's binary_logloss: 0.410151	valid's binary_logloss: 0.425339
# [4]	train's binary_logloss: 0.393464	valid's binary_logloss: 0.409953
# [5]	train's binary_logloss: 0.379546	valid's binary_logloss: 0.397353
# [6]	train's binary_logloss: 0.366353	valid's binary_logloss: 0.385933
# [7]	train's binary_logloss: 0.35547	valid's binary_logloss: 0.375836
# [8]	train's binary_logloss: 0.345813	valid's binary_logloss: 0.367582
# [9]	train's binary_logloss: 0.336773	valid's binary_logloss: 0.359922
# [10]	train's binary_logloss: 0.327859	valid's binary_logloss: 0.351782
# Final selected features {'weight', 'medical_keyword_5', 'medical_keyword_2', 'medical_info_a2', 'product', 'height', 'medical_keyword_4', 'medical_keyword_1', 'medical_info_a1', 'age', 'medical_keyword_3'}
